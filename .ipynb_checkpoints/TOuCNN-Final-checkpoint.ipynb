# %%
from numpy import nan
import matplotlib.pyplot as plt
from IPython.display import clear_output
from CNNOptimizer import CNNOptimizer

# %% [markdown]
# # Utility functions

# %%
def iter_print(x, history):
    clear_output(wait=True)
    title = (f'Iteration {len(history["Objective"]):03}:   '
             f'J={history["Objective"][-1]:0.3f}     '
             f'V={history["Volume"][-1]:0.3f}')
    plt.imshow(x, origin='lower', cmap='Greys', vmin=0, vmax=1, interpolation='nearest')
    plt.title(title)
    plt.tick_params(axis='both', which='both', colors='w')
    plt.show()

# %%
def optimize(opt):
    print(f'Optimization started.')
    x, time = opt.optimize(iter_print)
    print(f'Optimization finished in {time:0.2f} seconds.')
    ax = plt.subplots()[1]
    ax.plot(opt.history['Objective'] / max(opt.history['Objective']), label='Scaled Objective')
    ax.plot(opt.history['Volume'], label='Volume Fraction')
    ax.plot(opt.history['Gray'], label='Gray Elements')
    ax.legend()
    plt.ylim(0, 1)
    plt.show()

# %% [markdown]
# # Default configuration

# %%
options = {
    'use_gpu': True,
    'mesh_size': (256, 128),
    'symmetry_axis': None,
    'alpha_increase': 5,
    'penalty': 1, 'penalty_increase': 0.025,
    'min_it': 25, 'max_it': 500, 'converge_criteria': 0.02
}

# %% [markdown]
# # Tip-loaded cantilever example

# %%
bc = [{'S': (0, 0), 'E': (0, 1), 'D': (0, 0), 'F': 0},
      {'S': (1, 0), 'E': (1, 0), 'D': (nan, nan), 'F': lambda x, y: (0, -1)}]
options['volume_fraction'] = 0.75
options['learning_rate'] = 2.5E-4
optimizer = CNNOptimizer(bc, [], options)
optimize(optimizer)
# Out:
# Optimization finished in 83.52 seconds.

# %% [markdown]
# # Mid-loaded cantilever example

# %%
bc = [{'S': (0, 0), 'E': (0, 1), 'D': (0, 0), 'F': 0},
      {'S': (1, 0.5), 'E': (1, 0.5), 'D': (nan, nan), 'F': lambda x, y: (0, -1)}]
options['volume_fraction'] = 0.50
options['learning_rate'] = 1.5E-4
optimizer = CNNOptimizer(bc, [], options)
optimize(optimizer)
# Out:
# Optimization finished in 99.73 seconds.

# %% [markdown]
# # MBB beam example

# %%
bc = [{'S': (0, 0), 'E': (0, 1), 'D': (0, nan), 'F': 0},
      {'S': (1, 0), 'E': (1, 0), 'D': (nan, 0), 'F': 0},
      {'S': (0, 1), 'E': (0, 1), 'D': (nan, nan), 'F': lambda x, y: (0, -1)}]
options['volume_fraction'] = 0.45
options['learning_rate'] = 1.5E-4
optimizer = CNNOptimizer(bc, [], options)
optimize(optimizer)
# Out:
# Optimization finished in 113.93 seconds.

# %% [markdown]
# # Michell beam example

# %%
bc = [{'S': (0, 0), 'E': (0, 0), 'D': (0, 0), 'F': 0},
      {'S': (1, 0), 'E': (1, 0), 'D': (0, 0), 'F': 0},
      {'S': (0.5, 0), 'E': (0.5, 0), 'D': (nan, nan), 'F': lambda x, y: (0, -1)}]
options['volume_fraction'] = 0.30
options['learning_rate'] = 2.0E-4
options['symmetry_axis'] = 'Y'
optimizer = CNNOptimizer(bc, [], options)
optimize(optimizer)
# Out:
# Optimization finished in 50.35 seconds.

# %% [markdown]
# # Distributed load bridge example

# %%
bc = [{'S': (0, 0), 'E': (0, 0), 'D': (0, 0), 'F': 0},
      {'S': (1, 0), 'E': (1, 0), 'D': (0, 0), 'F': 0},
      {'S': (0, 1), 'E': (1, 1), 'D': (nan, nan), 'F': lambda x, y: (0, -0.01)}]
options['volume_fraction'] = 0.20
options['learning_rate'] = 1.0E-4
options['symmetry_axis'] = 'Y'
optimizer = CNNOptimizer(bc, [], options)
optimize(optimizer)
# Out:
# Optimization finished in 88.38 seconds.

# %% [markdown]
# # Bridge structure example

# %%
bc = [{'S': (0, 0), 'E': (0, 0), 'D': (nan, 0), 'F': 0},
      {'S': (1, 0), 'E': (1, 0), 'D': (nan, 0), 'F': 0},
      {'S': (0.50, 0), 'E': (0.50, 0), 'D': (nan, nan), 'F': lambda x, y: (0, -2)},
      {'S': (0.25, 0), 'E': (0.25, 0), 'D': (nan, nan), 'F': lambda x, y: (0, -1)},
      {'S': (0.75, 0), 'E': (0.75, 0), 'D': (nan, nan), 'F': lambda x, y: (0, -1)}]
options['volume_fraction'] = 0.40
options['learning_rate'] = 2.5E-4
options['symmetry_axis'] = 'Y'
optimizer = CNNOptimizer(bc, [], options)
optimize(optimizer)
# Out:
# Optimization finished in 47.98 seconds.
